# %%
import pandas as pd
from scipy import stats as sp
import streamlit as st
import plotly.express as px

df = pd.read_csv('../datasets/vehicles_us.csv')
df.head(10)
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# 5  14990      2014.0    chrysler 300  excellent        6.0  gas   57954.0
# 6  12990      2015.0    toyota camry  excellent        4.0  gas   79212.0
# 7  15990      2013.0     honda pilot  excellent        6.0  gas  109473.0
# 8  11500      2012.0     kia sorento  excellent        4.0  gas  104174.0
# 9   9200      2008.0     honda pilot  excellent        NaN  gas  147191.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# ...

# %%
# counting duplicate rows
df.duplicated().sum()

# Produce table with duplicates (with original rows included) and review last 5 rows
#dupl_rows = df[df.duplicated()]
#dupl_rows.tail(5)
# Out:
# 0

# %%
df['model_year'] = df['model_year'].fillna(df['model_year'].median())
df.head(10)
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500      2011.0      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas  113000.0
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# 5  14990      2014.0    chrysler 300  excellent        6.0  gas   57954.0
# 6  12990      2015.0    toyota camry  excellent        4.0  gas   79212.0
# 7  15990      2013.0     honda pilot  excellent        6.0  gas  109473.0
# 8  11500      2012.0     kia sorento  excellent        4.0  gas  104174.0
# 9   9200      2008.0     honda pilot  excellent        6.0  gas  147191.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV     Unknown     1.0  2018-06-23           19
# ...

# %%
df['cylinders'] = df.groupby('model')['cylinders'].fillna(df['cylinders'].median())
df.head(10)
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# 5  14990      2014.0    chrysler 300  excellent        6.0  gas   57954.0
# 6  12990      2015.0    toyota camry  excellent        4.0  gas   79212.0
# 7  15990      2013.0     honda pilot  excellent        6.0  gas  109473.0
# 8  11500      2012.0     kia sorento  excellent        4.0  gas  104174.0
# 9   9200      2008.0     honda pilot  excellent        6.0  gas  147191.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV     Unknown     1.0  2018-06-23           19
# ...

# %%
df['odometer'] = df.groupby('model')['odometer'].fillna(df['odometer'].median())
df.head(10)
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas  113000.0
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# 5  14990      2014.0    chrysler 300  excellent        6.0  gas   57954.0
# 6  12990      2015.0    toyota camry  excellent        4.0  gas   79212.0
# 7  15990      2013.0     honda pilot  excellent        6.0  gas  109473.0
# 8  11500      2012.0     kia sorento  excellent        4.0  gas  104174.0
# 9   9200      2008.0     honda pilot  excellent        6.0  gas  147191.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV     Unknown     1.0  2018-06-23           19
# ...

# %%
df['paint_color'] = df['paint_color'].fillna('Unknown')
#df.head(10)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
df['is_4wd'] = df['is_4wd'].fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
#df.info()
df = df.sort_values(by='odometer', ascending=True)
print(df[(df['odometer']> 0) & (df['odometer']<100)])
# Out:
#        price  model_year             model  condition  cylinders fuel  \
# 23987      1      2007.0   chevrolet tahoe   like new        NaN  gas
# 31124   9500      2000.0     toyota tundra       good        8.0  gas
# 23811      1      2007.0   chevrolet tahoe   like new        8.0  gas
# 3695    2995      1992.0      ford mustang       fair        4.0  gas
# 23804      1      2007.0   chevrolet tahoe   like new        8.0  gas
# ...      ...         ...               ...        ...        ...  ...
# 25242  32500      1968.0  chevrolet camaro  excellent        8.0  gas
# 38846  10900         NaN         ford edge   like new        6.0  gas
# 40332   3975      2004.0  chevrolet impala  excellent        6.0  gas
# 24762   7595      2011.0      toyota camry  excellent        4.0  gas
# 3124    7100      2008.0        honda cr-v  excellent        4.0  gas
#
#        odometer transmission         type paint_color  is_4wd date_posted  \
# ...

# %%
#model_price_selector1 = df['model'].unique()
model_price_selector1 = 'bmw x5'
#model_dropbox1 = st.selectbox('Select first Model: ', model_price_selector1)
df_model1 = df[df['model'] == model_price_selector1]       #model_dropbox1]

#model_price_selector2 = df['model'].unique()
model_price_selector2 = 'chevrolet camaro'
#model_dropbox2 = st.selectbox('Select second Model: ', model_price_selector2)
df_model2 = df[df['model'] == model_price_selector2]         #model_dropbox2]

df_merged = pd.concat([df_model1, df_model2], axis=0)

df_merged
# Out:
#        price  model_year             model  condition  cylinders    fuel  \
# 44353  14995      2013.0            bmw x5  excellent        6.0     gas
# 21233   1900      2004.0            bmw x5       good        6.0     gas
# 23443  10500      2011.0            bmw x5  excellent        6.0  diesel
# 37716   5900      2007.0            bmw x5  excellent        6.0     gas
# 50851  23000      2012.0            bmw x5   like new        6.0     gas
# ...      ...         ...               ...        ...        ...     ...
# 43331  31000      2017.0  chevrolet camaro       good        8.0     gas
# 43455  15997      2010.0  chevrolet camaro   like new        NaN     gas
# 44813   1500      1997.0  chevrolet camaro       good        6.0     gas
# 48291   8995      2013.0  chevrolet camaro       good        6.0     gas
# 49969  14961      2015.0  chevrolet camaro  excellent        6.0     gas
#
#        odometer transmission         type paint_color  is_4wd date_posted  \
# ...

# %%
df['transmission'].unique()
# Out:
# array(['automatic', 'manual', 'other'], dtype=object)

# %%
df['paint_color'].unique()
# Out:
# array([nan, 'custom', 'blue', 'black', 'red', 'green', 'white', 'silver',
#        'grey', 'yellow', 'brown', 'purple', 'orange'], dtype=object)

# %%
st.header('Car Types by Manufacturer')
fig = px.histogram(df, x='model', color='model_year')
st.write(fig)
# Out:
# 2025-01-12 22:36:08.971
# ...
#   command:
#
#     streamlit run c:\Users\pamad\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
st.header('Car Types by Manufacturer')
fig = px.histogram(df, x='model', color='type')
st.write(fig)
